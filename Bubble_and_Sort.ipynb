# %% [markdown]
# <a href="https://colab.research.google.com/github/SonwabileBanca/SonwabileBanca.github.io/blob/main/Bubble_and_Sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Sorting Algorithms:
import numpy as np
import matplotlib.pyplot as plt
# The number of elements in the array
################
amount = 10
lst = np.random.randint(0, 100, amount)
x = np.arange(0, amount, 1)
#Bubble Sort algorithm
n = len(lst)
#For loop in range of the length of the list
for i in range(n):
  for j in range(0, n-i-1):
    #Start plotting the graph
    plt.bar(x, lst)
    plt.pause(0.01)
    plt.clf()
    if lst[j] > lst[j+1]:
      lst[j], lst[j+1] = lst[j+1], lst[j]

plt.show()
